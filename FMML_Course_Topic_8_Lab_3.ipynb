# %% [markdown]
# <a href="https://colab.research.google.com/github/DheerajVenkatesh/FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 11:34:47--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   250MB/s    in 0.3s
#
# 2024-03-31 11:34:47 (250 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10327   1204.4539v3  We consider supervised learning problems where...  stat
# 29118  1708.04673v2  We study the problem of acoustic feature learn...    cs
# 21551   1006.3640v2  Density modeling is notoriously difficult for ...  stat
# 25450  1509.02130v1  We address the task of annotating images with ...    cs
# 6123   1607.08810v1  Polynomial networks and factorization machines...  stat
# ...             ...                                                ...   ...
# 16847  1706.07503v3  The main goal of modeling human conversation i...    cs
# 21028  1706.08317v1  Temporal landmarks have been proved to be a he...    cs
# 18207  cs/0603120v1  In this paper, we study clustering with respec...    cs
# 9707   1709.07267v1  In recent years, the number of papers on Alzhe...  stat
# 29408  1709.03138v1  One of the most important parts of environment...    cs
#
#                                                    title  year  \
# 10327  Supervised Feature Selection in Graphs with Pa...  2012
# 29118  Acoustic Feature Learning via Deep Variational...  2017
# 21551  Gaussian Mixture Modeling with Gaussian Proces...  2010
# 25450  Structured Prediction with Output Embeddings f...  2015
# 6123   Polynomial Networks and Factorization Machines...  2016
# ...                                                  ...   ...
# 16847            Personalization in Goal-Oriented Dialog  2017
# 21028  Handling PDDL3.0 State Trajectory Constraints ...  2017
# 18207    Approximation Algorithms for K-Modes Clustering  2006
# 9707   Yet Another ADNI Machine Learning Paper? Pavin...  2017
# 29408  Fully Convolutional Neural Networks for Dynami...  2017
#
#                                                 keywords
# 10327  [supervised, expressions, automatically, conne...
# 29118  [variational, canonical, correlation, generati...
# 21551  [notoriously, difficult, dimensional, dimensio...
# 25450  [annotating, algorithm, challenge, available, ...
# 6123   [polynomial, factorization, efficiently, inter...
# ...                                                  ...
# 16847  [conversation, scenarios, important, generaliz...
# 21028  [landmarks, mechanism, specifically, performan...
# 18207  [clustering, objective, formulation, clusterin...
# 9707   [alzheimers, classification, increased, dramat...
# 29408  [important, environment, perception, detection...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10327    [supervised, expressions, automatically, conne...
# 29118    [variational, canonical, correlation, generati...
# 21551    [notoriously, difficult, dimensional, dimensio...
# 25450    [annotating, algorithm, challenge, available, ...
# 6123     [polynomial, factorization, efficiently, inter...
#                                ...
# 6244     [supervised, supervised, classifiers, addition...
# 7482     [expectation, maximization, algorithm, expecta...
# 22966    [independent, component, technique, unsupervis...
# 26953    [compressive, resulting, resolution, drawbacks...
# 33071    [inductive, convolutional, substantially, outp...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8840 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c2d39b8b-6879-43cf-af9f-4aeb4d214600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c2d39b8b-6879-43cf-af9f-4aeb4d214600")) {                    Plotly.newPlot(                        "c2d39b8b-6879-43cf-af9f-4aeb4d214600",                        [{"x":["penalties","performance","structured","experimentally","knowledge","leveraging","supervised","tractable","synthetic","selecting","interactions","algorithmic","prediction","efficiently","interpret","exploiting","components","strategies","operators","functions","combinatorially","optimization","expressions","introduce","automatically","subgraphs","typically","selection","challenges","connected","regularization","computationally","recognition","intuitive","variational","generative","techniques","extensions","interpretation","independent","correlation","advantages","adversarial","university","objective","canonical","representation","therefore","difficult","manifolds","notoriously","estimates","interpreted","comparative","stochastic","evaluations","benchmark","generalisation","successfully","dimensional","characteristics","annotation","integrating","challenge","representations","annotating","available","incorporating","predictions","algorithm","factorized","flexibility","embeddings","experiments","factorization","parameter","symmetric","classification","estimation","perspective","efficient","regression","algorithms","properties","demonstrate","polynomial","recommender","assessment","community","continues","compression","particularly","degradations","different","streaming","artifacts","consisting","significant","preliminary","perceived","relationship","reference","distortions","convolutional","tremendous","leverages","confident","including","forecasting","conjunction","resurgence","allocation","variables","detection","uncertainty","motivated","classical","completed","manufacturing","probabilistic","exogenous","incentive","formulation","consistency","equivalent","weighting","existence","universal","simulated","consequences","illustrated","empirical","minimization","percentage","architectures","supporting","prioritizes","competitive","requirements","modalities","extensibility","pedagogical","translation","maintaining","documentation","modularity","underlying","reasonable","efficiency","isomorphism","subsequently","orthogonal","consistent","conclusion","isomorphic","suggested","prospects","resulting","dimensionality","dimensions","reduction","multiplying","dimension","investigate","supervisor","classifier","originally","widespread","outperforms","neighbors","architecture","mechanisms","exploited","collected","characterize","structures","computational","olfactory","alternative","structural","intrinsic","potentially","substantially","limitations","complementary","inhibition","plasticity","illustrates","biological","cluttered","emergence","hierarchical","eliminate","expecting","transformer","approximation","geometric","researchers","implement","interference"],"y":[4,891,94,45,347,51,189,29,124,51,77,39,244,171,28,65,105,89,55,195,0,324,39,336,181,3,94,163,114,69,73,89,399,30,50,125,388,37,52,129,77,92,116,20,166,15,356,129,143,11,6,69,18,29,127,62,208,12,82,177,84,59,42,144,263,13,295,66,87,800,4,32,76,588,41,128,18,491,199,75,387,111,586,208,545,66,21,38,69,11,40,82,4,754,14,18,43,231,47,14,81,65,13,371,11,24,5,254,15,22,2,32,145,358,74,82,104,6,5,159,3,3,84,63,58,24,28,38,58,13,19,151,74,14,99,22,2,121,44,36,5,3,119,41,7,7,142,36,156,1,29,21,102,18,1,23,2,164,59,44,115,1,64,163,1,152,14,11,266,18,264,60,38,65,59,134,263,2,114,68,41,52,47,73,30,2,13,6,47,14,17,113,14,1,5,129,75,62,66,6],"type":"bar"},{"x":["penalties","performance","structured","experimentally","knowledge","lev ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8016666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Popular</span> <span style=''>Ensemble</span> <span style=''>Methods</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Study</span> <br/><br/><span style=''>An</span> <span style=''>ensemble</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individually</span> <span style=''>trained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>(such</span> <span style=''>as</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>or</span> <span style=''>decision</span> <span style=''>trees)</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictions</span> <span style=''>are</span> <span style=''>combined</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3972602739726026);'>classifying</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3108108108108108);'>instances</span> <span style=''>Previous</span> <span style=''>research</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>is</span> <span style=''>often</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>than</span> <span style=''>any</span> <span style=''>of</span> <span style=''>the</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ensemble</span> <span style=''>Bagging</span> <span style=''>(Breiman</span> <span style=''>1996c)</span> <span style=''>and</span> <span style=''>Boosting</span> <span style=''>(Freund</span> <span style=''>and</span> <span style=''>Shapire</span> <span style=''>1996</span> <span style=''>Shapire</span> <span style=''>1990)</span> <span style=''>are</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relatively</span> <span style=''>new</span> <span style=''>but</span> <span style=''>popular</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>producing</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>ensembles</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>evaluate</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>on</span> <span style=''>23</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>using</span> <span style=''>both</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>as</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>Our</span> <span style=''>results</span> <span style=''>clearly</span> <span style=''>indicate</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conclusions</span> <span style=''>First</span> <span style=''>while</span> <span style=''>Bagging</span> <span style=''>is</span> <span style=''>almost</span> <span style=''>always</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>than</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style=''>much</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributions</span> <span style=''>using</span> <span style=''>Dirac</span> <span style=''>Kernels</span> <span style=''>(via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Rademacher</span> <span style=''>Walsh</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Polynomial</span> <span style=''>Basis</span> <span style=''>Functions)</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>(in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>systems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>pattern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cheminformatics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bioinformatics</span> <span style=''>to</span> <span style=''>name</span> <span style=''>but</span> <span style=''>a</span> <span style=''>few)</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessment</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essential</span> <span style=''>ie</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>function</span> <span style=''>More</span> <span style=''>often</span> <span style=''>than</span> <span style=''>not</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>this</span> <span style=''>function</span> <span style=''>is</span> <span style=''>unknown</span> <span style=''>and</span> <span style=''>it</span> <span style=''>becomes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>necessary</span> <span style=''>to</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrically</span> <span style=''>constructestimate</span> <span style=''>it</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style=''>sample</span> <span style=''>One</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>of</span> <span style=''>choice</span> <span style=''>to</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrically</span> <span style=''>estimate</span> <span style=''>the</span> <span style=''>unknown</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>function</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>(defined</span> <span style=''>on</span> <span style=''>binary</span> <span style=''>space)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>function</span> <span style=''>in</span> <span style='background ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Sparse</span> <span style=''>Group</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>Nonconvex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Sparse</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>has</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.30708661417322836);'>effective</span> <span style=''>in</span> <span style=''>handling</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.36445242369838426);'>dimensional</span> <span style=''>data</span> <span style=''>While</span> <span style='background-color:rgba(0, 255, 0, 0.3892215568862275);'>promising</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>works</span> <span style=''>use</span> <span style=''>convex</span> <span style=''>methods</span> <span style=''>which</span> <span style=''>may</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>expand</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>nonconvex</span> <span style=''>paradigm</span> <span style=''>to</span> <span style=''>sparse</span> <span style=''>group</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>that</span> <span style=''>require</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identifying</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>group</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>of</span> <span style=''>this</span> <span style=''>article</span> <span style=''>are</span> <span style=''>twofold</span> <span style=''>(1)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistically</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.380952380952381);'>nonconvex</span> <span style=''>sparse</span> <span style=''>group</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>model</span> <span style=''>which</span> <span style=''>can</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>TCAV</span> <span style=''>Relative</span> <span style=''>concept</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>testing</span> <span style=''>with</span> <span style=''>Linear</span> <span style=''>Concept</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Activation</span> <span style=''>Vectors</span> <br/><br/><span style=''>Neural</span> <span style=''>networks</span> <span style=''>commonly</span> <span style=''>offer</span> <span style=''>high</span> <span style=''>utility</span> <span style=''>but</span> <span style=''>remain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Developing</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>explain</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decisions</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>due</span> <span style=''>to</span> <span style=''>their</span> <span style=''>large</span> <span style=''>size</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>inscrutable</span> <span style=''>internal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>This</span> <span style=''>work</span> <span style=''>argues</span> <span style=''>that</span> <span style=''>the</span> <span style=''>language</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanations</span> <span style=''>should</span> <span style=''>be</span> <span style=''>expanded</span> <span style=''>from</span> <span style=''>that</span> <span style=''>of</span> <span style=''>input</span> <span style=''>features</span> <span style=''>(eg</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assigning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>weightings</span> <span style=''>to</span> <span style=''>pixels)</span> <span style=''>to</span> <span style=''>include</span> <span style=''>that</span> <span style=''>of</span> <span style=''>higher</span> <span style=''>level</span> <span style=''>human</span> <span style=''>friendly</span> <span style=''>concepts</span> <span style=''>For</span> <span style=''>example</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understandable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>of</span> <span style=''>why</span> <span style=''>an</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>outputs</span> <span style=''>the</span> <span style=''>label</span> <span style=''>zebra</span> <span style=''>would</span> <span style=''>ideally</span> <span style=''>relate</span> <span style=''>to</span> <span style=''>concepts</span> <span style=''>such</span> <span style=''>as</span> <span style=''>stripes</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>pixel</span> <span style=''>values</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>the</span> <span style=''>concept</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>vector</span> <span style=''>(CAV)</span> <span style=''>which</span> <span style=''>allows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitative ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representations (0.09359430604982207)
# 	segmentation (0.0597864768683274)
# 	representation (0.12669039145907474)
# 	knowledge (0.12348754448398576)
# 	information (0.24448398576512456)
# 	architecture (0.09395017793594305)
# 	different (0.2683274021352313)
# 	detection (0.12740213523131672)
# 	convolutional (0.1320284697508897)
# 	recognition (0.14199288256227757)
#
# Some Statistics words are:
# 	stochastic (0.13417085427135678)
# 	algorithms (0.2994974874371859)
# 	theoretical (0.1577889447236181)
# 	statistical (0.1577889447236181)
# 	estimation (0.17688442211055277)
# 	algorithm (0.39849246231155777)
# 	distribution (0.18090452261306533)
# 	dimensional (0.19095477386934673)
# 	inference (0.19949748743718593)
# 	regression (0.1798994974874372)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1b7e4b29-2bbf-4067-8fa3-d116b2e66406" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b7e4b29-2bbf-4067-8fa3-d116b2e66406")) {                    Plotly.newPlot(                        "1b7e4b29-2bbf-4067-8fa3-d116b2e66406",                        [{"x":["penalties","performance","structured","experimentally","knowledge","leveraging","supervised","tractable","synthetic","selecting","interactions","algorithmic","prediction","efficiently","interpret","exploiting","components","strategies","operators","functions","combinatorially","optimization","expressions","introduce","automatically","subgraphs","typically","selection","challenges","connected","regularization","computationally","recognition","intuitive","variational","generative","techniques","extensions","interpretation","independent","correlation","advantages","adversarial","university","objective","canonical","representation","therefore","difficult","manifolds","notoriously","estimates","interpreted","comparative","stochastic","evaluations","benchmark","generalisation","successfully","dimensional","characteristics","annotation","integrating","challenge","representations","annotating","available","incorporating","predictions","algorithm","factorized","flexibility","embeddings","experiments","factorization","parameter","symmetric","classification","estimation","perspective","efficient","regression","algorithms","properties","demonstrate","polynomial","recommender","assessment","community","continues","compression","particularly","degradations","different","streaming","artifacts","consisting","significant","preliminary","perceived","relationship","reference","distortions","convolutional","tremendous","leverages","confident","including","forecasting","conjunction","resurgence","allocation","variables","detection","uncertainty","motivated","classical","completed","manufacturing","probabilistic","exogenous","incentive","formulation","consistency","equivalent","weighting","existence","universal","simulated","consequences","illustrated","empirical","minimization","percentage","architectures","supporting","prioritizes","competitive","requirements","modalities","extensibility","pedagogical","translation","maintaining","documentation","modularity","underlying","reasonable","efficiency","isomorphism","subsequently","orthogonal","consistent","conclusion","isomorphic","suggested","prospects","resulting","dimensionality","dimensions","reduction","multiplying","dimension","investigate","supervisor","classifier","originally","widespread","outperforms","neighbors","architecture","mechanisms","exploited","collected","characterize","structures","computational","olfactory","alternative","structural","intrinsic","potentially","substantially","limitations","complementary","inhibition","plasticity","illustrates","biological","cluttered","emergence","hierarchical","eliminate","expecting","transformer","approximation","geometric","researchers","implement","interference","disadvantages","displacement","handwritten","distortion","alignment","deformation","transformation","adversary","adversaries","addressing","disclosed","manipulating","constructed","obscurity","solutions","robustness","confidence","susceptible","essential","generating","autonomous","applications","correctly","protected","integrates","resistance","particular","potential","classified","guaranteed","technique","comparison","fundamental","specifically","resistant","generality","effective","previously","improvements","augmentation","applicable","multitask","structure","formalized","euclidean","complexity","iteratively","observation","denoising","implemented","comparable","reweighted","replacing","attempted","discussed","signature ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	combinatorially
# 	normality
# 	gracefully
# 	posteriors
# 	stepsizes
# 	spectroscopy
# 	depression
# 	multinomial
# 	cytometric
# 	cytometry
# 	searchlight
# 	homomorphic
# 	statisticians
# 	connectomics
# 	connectome
# 	quadratures
# 	metropolis
# 	deconvnet
# 	alleviated
# 	correntropy
# Some words which never appear in Statistics papers:
# 	annotating
# 	prioritizes
# 	extensibility
# 	olfactory
# 	inhibition
# 	transformer
# 	deformation
# 	obscurity
# 	intrusions
# 	timescale
# 	attentional
# 	authentication
# 	smartphone
# 	smartphones
# 	morphologically
# 	intrusive
# 	silhouettes
# 	evidences
# 	attachments
# 	attachment

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061005846521167e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
